# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('foodwastedata.csv')
list(df.columns)
df.sort_values(by=['combined figures (kg/capita/year)'])
df.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...
